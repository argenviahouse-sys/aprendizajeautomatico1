# %% [markdown]
# <a href="https://colab.research.google.com/github/argenviahouse-sys/aprendizajeautomatico1/blob/main/primer%2Cejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TEXTO
# CARGA DE LOS DATA SET
# VIDEO TUTORIAL
# ENLACE SUGERIDO: https://archive.ics.uci.edu/dataset/484/travel+reviews
#
# dentro de este enlace, buscamos el archivo de descarga y usamos el url para bajar el archivo .zip o el que sea.

# %% [markdown]
# primera parte:

# %%
url = "https://archive.ics.uci.edu/static/public/484/travel+reviews.zip"

# %% [markdown]
# solo uso un "espacio de codigo"/ CELL / "CELDA"
#
# se puede correr el comando presionando CTRL+ENTER o sino con el puntero sobre el logo de "play"

# %%
! wget https://archive.ics.uci.edu/static/public/484/travel+reviews.zip
# Out:
# --2026-04-19 16:56:31--  https://archive.ics.uci.edu/static/public/484/travel+reviews.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘travel+reviews.zip’
#
# travel+reviews.zip      [ <=>                ]  56.10K  --.-KB/s    in 0.1s
#
# 2026-04-19 16:56:31 (580 KB/s) - ‘travel+reviews.zip’ saved [57449]

# %% [markdown]
# se **aplico** ! y luego boton "play" para correr el comando. Fue exitoso y guardo en "travel-reviews" (indica MB y FECHA)
#
# SI abrimos la carpeta de la derecha veremos la secciones FILES con sus carpetas y archivos

# %%
! ls
# Out:
# sample_data  travel+reviews.zip

# %% [markdown]
# SE HA APLICADO ! LS para observar dentro de la misma celda la informacion sobre donde se guardo el archivo descargado previamente.
# LO MISMO MENCIONADO ARRIBA: ORDEN RE FILES, NOMBRE_CARPETA, NOMBRE_ARCHIVO.

# %% [markdown]
# Se ha aplicado UNZIP, que es un comando incluido en colab.
# Luego el archivo se guarda en col colab environment (virtual)

# %%
! unzip travel+reviews.zip
# Out:
# Archive:  travel+reviews.zip
#  extracting: tripadvisor_review.csv

# %% [markdown]
# podemos volver a comprobar si se descargo y veremos el tipo de archivo descargado en este caso .csv

# %%
! ls
# Out:
# sample_data  travel+reviews.zip  tripadvisor_review.csv

# %% [markdown]
# se le pidio a la IA que genere una secuencia para cargar el archivo .csv
# lo que da como resultado que abra el archivo y muestre la informacion desplegada de cierta forma

# %% [markdown]
# se puede ver que la ia genero la variable DF y le dio la funcion de leer .csv
#
# ahora si necesito agregar mas funciones hay que llamar a DF y este hara la funcion de leer lo que pedí...
# pd.read_csv

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('tripadvisor_review.csv')

# Display the first few rows of the DataFrame to confirm it loaded correctly
print(df.head())
# Out:
#   User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0  User 1        0.93         1.8        2.29        0.62        0.80
# 1  User 2        1.02         2.2        2.66        0.64        1.42
# 2  User 3        1.22         0.8        0.54        0.53        0.24
# 3  User 4        0.45         1.8        0.29        0.57        0.46
# 4  User 5        0.51         1.2        1.18        0.57        1.54
#
#    Category 6  Category 7  Category 8  Category 9  Category 10
# 0        2.42        3.19        2.79        1.82         2.42
# 1        3.18        3.21        2.63        1.86         2.32
# 2        1.54        3.18        2.80        1.31         2.50
# 3        1.52        3.18        2.96        1.57         2.86
# 4        2.02        3.18        2.78        1.18         2.54

# %% [markdown]
# se puede ver que en este caso no es igual que el video de la clase, ya que la IA no generó una leyenda al descargar el archivo, entonces... procedo a hacerlo mas abajo, primero) preguntadole a la IA otra vez con otro prompt mas claro

# %%
import pandas as pd

# Cargar el archivo CSV
df = pd.read_csv('tripadvisor_review.csv')

# Mostrar mensaje de éxito
print("carga exitosa")
# Out:
# carga exitosa

# %% [markdown]
# en este caso importo pandas y mostro el mensaje (pero a diferencia del video, la ia escribio un comando mas corto y basado en mi texto "carga exitosa") (tambien vemos que no muestra las filas y columnas como hizo antes...

# %%
df
# Out:
#       User ID  Category 1  Category 2  Category 3  Category 4  Category 5  \
# 0      User 1        0.93        1.80        2.29        0.62        0.80
# 1      User 2        1.02        2.20        2.66        0.64        1.42
# 2      User 3        1.22        0.80        0.54        0.53        0.24
# 3      User 4        0.45        1.80        0.29        0.57        0.46
# 4      User 5        0.51        1.20        1.18        0.57        1.54
# ..        ...         ...         ...         ...         ...         ...
# 975  User 976        0.74        1.12        0.30        0.53        0.88
# 976  User 977        1.25        0.92        1.12        0.38        0.78
# 977  User 978        0.61        1.32        0.67        0.43        1.30
# 978  User 979        0.93        0.20        0.13        0.43        0.30
# 979  User 980        0.93        0.56        1.13        0.51        1.34
#
#      Category 6  Category 7  Category 8  Category 9  Category 10
# ...

# %% [markdown]
# usando el comando DF dataframe... inicia y muestra los datos cargados en el .csv. hay 1000 x 10 datos...

# %% [markdown]
# a la ia se dio un nuevo prompt de la clase:
#
# prompt.
#
# mediante el marco de datos df: un resumen de los principales indicadores estadísticos de df

# %%
print(df.describe())
# Out:
#        Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# count  980.000000  980.000000  980.000000  980.000000  980.000000  980.000000
# mean     0.893194    1.352612    1.013306    0.532500    0.939735    1.842898
# std      0.326912    0.478280    0.788607    0.279731    0.437430    0.539538
# min      0.340000    0.000000    0.130000    0.150000    0.060000    0.140000
# 25%      0.670000    1.080000    0.270000    0.410000    0.640000    1.460000
# 50%      0.830000    1.280000    0.820000    0.500000    0.900000    1.800000
# 75%      1.020000    1.560000    1.572500    0.580000    1.200000    2.200000
# max      3.220000    3.640000    3.620000    3.440000    3.300000    3.760000
#
#        Category 7  Category 8  Category 9  Category 10
# count  980.000000  980.000000  980.000000   980.000000
# mean     3.180939    2.835061    1.569439     2.799224
# std      0.007824    0.137505    0.364629     0.321380
# ...

# %% [markdown]
# finalmente pude continuar, es necesario cargar todos los archivos nuevamente despues de cerrar sesion.
# ademas verificar los nombres de los archivos ya que podrian tener alguna diferencia si los cambiamos en la sesion anterior **-ej: .zip en lugar de.zip1 **

# %%
df.shape
# Out:
# (980, 11)

# %%
podemos ver que DF es una variable ya definida
si no cargo otra vez el proceso en las celdas,
tiende a perder el nombre de la variable
y no llamara a hacer nada.
reiniciar "run" para definirla

# %% [markdown]
# termino la actividad

# %% [markdown]
# nueva actividad_
# dataset_
# analisis de sentimiento

# %% [markdown]
# primero intentamos un prompt con la ia... le vamos a decir:
#
# Descargar el .zip desde https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip, descomprimirlo, cargar en variable dataset el archivo csv

# %%
# 1. Descargar el archivo ZIP
# !wget https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip

# 2. Descomprimir el archivo ZIP
# !unzip sentiment+labelled+sentences.zip

# 3. Mostrar los archivos descomprimidos para identificar el CSV
# (Este dataset suele contener múltiples archivos .txt que son tab-separated)
# !ls

# 4. Cargar uno de los archivos .txt (e.g., yelp_labelled.txt) en la variable dataset
# Asumiendo que es un archivo tab-separated sin encabezado y dos columnas (texto, etiqueta)
import pandas as pd

try:
    # Intenta cargar 'yelp_labelled.txt' como ejemplo
    dataset = pd.read_csv('yelp_labelled.txt', sep='\t', header=None, names=['sentence', 'sentiment'])
    print("Archivo 'yelp_labelled.txt' cargado exitosamente en la variable 'dataset'.")
    print(dataset.head())
except FileNotFoundError:
    print("No se encontró 'yelp_labelled.txt'. Por favor, verifica los archivos descomprimidos y ajusta el nombre si es necesario.")
except Exception as e:
    print(f"Ocurrió un error al cargar el archivo: {e}")
# Out:
# --2026-04-19 17:46:21--  https://archive.ics.uci.edu/static/public/331/sentiment+labelled+sentences.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘sentiment+labelled+sentences.zip.1’
#
# sentiment+labelled+     [ <=>                ]  82.21K  --.-KB/s    in 0.1s
#
# 2026-04-19 17:46:22 (831 KB/s) - ‘sentiment+labelled+sentences.zip.1’ saved [84188]
#
# Archive:  sentiment+labelled+sentences.zip
# replace sentiment labelled sentences/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:  __MACOSX			    sentiment+labelled+sentences.zip.1
#  sample_data			    travel+reviews.zip
# 'sentiment labelled sentences'	    tripadvisor_review.csv
#  sentiment+labelled+sentences.zip
# ...

# %% [markdown]
# aca la ia ordenó el codigo de otra forma:
# wget
# unzip
# ls
# import aaaaa as a
#
# tambien vemos que sale un mensaje de "no se encontro yelp_l_txt" ... quizas porque esta dentro de otra carpeta primero, hay que ver... mas adelante escribo esto nuevamente

# %%
! ls
# Out:
#  __MACOSX     'sentiment labelled sentences'	  travel+reviews.zip
#  sample_data   sentiment+labelled+sentences.zip   tripadvisor_review.csv

# %% [markdown]
# aca se copia y pega el comando HEAD con el nombre de carpeta separado por las barras invertidas...
# esta es la forma de abrir los archivos, indicando la carpeta donde pertenecen.
# si hay espacios entonces usar barra
#  \\\\espacio ////direccion

# %%
! head sentiment\ labelled\ sentences/amazon_cells_labelled.txt
# Out:
# So there is no way for me to plug it in here in the US unless I go by a converter.	0
# Good case, Excellent value.	1
# Great for the jawbone.	1
# Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!	0
# The mic is great.	1
# I have to jiggle the plug to get it to line up right to get decent volume.	0
# If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.	0
# If you are Razr owner...you must have this!	1
# Needless to say, I wasted my money.	0
# What a waste of money and time!.	0

# %% [markdown]
# se le ha pedido a la ia que genere codigo mediante el prompt:
# buscar y mostrar con head, el archivo: yelp_labelled.txt

# %%
# !head sentiment\ labelled\ sentences/yelp_labelled.txt
# Out:
# Wow... Loved this place.	1
# Crust is not good.	0
# Not tasty and the texture was just nasty.	0
# Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.	1
# The selection on the menu was great and so were the prices.	1
# Now I am getting angry and I want my damn pho.	0
# Honeslty it didn't taste THAT fresh.)	0
# The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.	0
# The fries were great too.	1
# A great touch.	1

# %% [markdown]
# # prompt: cargar el dataset amazon_cells_labelled.txt del directorio sentiment labelled sentences

# %%
import pandas as pd

# Ruta al archivo
file_path = 'sentiment labelled sentences/amazon_cells_labelled.txt'

# Cargar el archivo en un DataFrame, especificando el separador y los nombres de las columnas
amazon_df = pd.read_csv(file_path, sep='\t', header=None, names=['sentence', 'sentiment'])

# Mostrar las primeras filas del DataFrame para verificar la carga
print(amazon_df.head())
# Out:
#                                             sentence  sentiment
# 0  So there is no way for me to plug it in here i...          0
# 1                        Good case, Excellent value.          1
# 2                             Great for the jawbone.          1
# 3  Tied to charger for conversations lasting more...          0
# 4                                  The mic is great.          1

# %% [markdown]
# cambio de nombre de variable
# dataset (en video) por amazon_df (prompt ia)
#
# entonces se procede a describe() sobre la variable nombrada, prestar atencion a los nombres que ia da aca, puede ser diferente a los videos o proyectos de otras personas

# %%
amazon_df.describe()
# Out:
#         sentiment
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
amazon_df.shape
# Out:
# (1000, 2)

# %% [markdown]
# aca termina la actividad.
# importante: nombres de variables
# cargar los archivos antes de run/correr
